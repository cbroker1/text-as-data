# %% [markdown]
# # 1. User Reviews via Steam API (https://partner.steamgames.com/doc/store/getreviews)

# %%
# import packages
import os
import sys
import time
import json
import numpy as np
import urllib.parse
import urllib.request
from tqdm import tqdm
import plotly.express as px
from datetime import datetime
from googletrans import Translator

import pandas as pd
from pandas import json_normalize

# list package ver. etc.
print("Python version")
print (sys.version)
print("Version info.")
print (sys.version_info)
print('---------------')
# Out:
# Python version
# 3.8.3 (default, May 19 2020, 18:47:26)
# [GCC 7.3.0]
# Version info.
# sys.version_info(major=3, minor=8, micro=3, releaselevel='final', serial=0)
# ---------------

# %% [markdown]
# ---
# ### Data Dictionary:
#
# - Response:
#     - success - 1 if the query was successful
#     - query_summary - Returned in the first request
#         - recommendationid - The unique id of the recommendation
#         - author
#             - steamid - the user’s SteamID
#             - um_games_owned - number of games owned by the user
#             - num_reviews - number of reviews written by the user
#             - playtime_forever - lifetime playtime tracked in this app
#             - playtime_last_two_weeks - playtime tracked in the past two weeks for this app
#             - playtime_at_review - playtime when the review was written
#             - last_played - time for when the user last played
#         - language - language the user indicated when authoring the review
#         - review - text of written review
#         - timestamp_created - date the review was created (unix timestamp)
#         - timestamp_updated - date the review was last updated (unix timestamp)
#         - voted_up - true means it was a positive recommendation
#         - votes_up - the number of users that found this review helpful
#         - votes_funny - the number of users that found this review funny
#         - weighted_vote_score - helpfulness score
#         - comment_count - number of comments posted on this review
#         - steam_purchase - true if the user purchased the game on Steam
#         - received_for_free - true if the user checked a box saying they got the app for free
#         - written_during_early_access - true if the user posted this review while the game was in Early Access
#         - developer_response - text of the developer response, if any
#         - timestamp_dev_responded - Unix timestamp of when the developer responded, if applicable
#
# ---
# Source: https://partner.steamgames.com/doc/store/getreviews

# %% [markdown]
# ## 1.1 Import

# %%
# generate game review df

#steam 'chunks' their json files (the game reviews) in sets of 100
#ending with a signature, a 'cursor'. This cursor is then pasted
#onto the the same url, to 'grab' the next chunk and so on. 
#This sequence block with an 'end cursor' of 'AoJ4tey90tECcbOXSw=='

#set variables
url_base = 'https://store.steampowered.com/appreviews/393380?json=1&filter=updated&language=all&review_type=all&purchase_type=all&num_per_page=100&cursor='

#first pass
url = urllib.request.urlopen("https://store.steampowered.com/appreviews/393380?json=1&filter=updated&language=all&review_type=all&purchase_type=all&num_per_page=100&cursor=*")
data = json.loads(url.read().decode())
next_cursor = data['cursor']
next_cursor = next_cursor.replace('+', '%2B')
df1 = json_normalize(data['reviews'])
print(next_cursor)

#add results till stopcursor met, then send all results to csv
while True:
    time.sleep(0.5) # Sleep for one second
    url_temp = url_base + next_cursor
    url = urllib.request.urlopen(url_temp)
    data = json.loads(url.read().decode())
    next_cursor = data['cursor']
    next_cursor = next_cursor.replace('+', '%2B')
    df2 = json_normalize(data['reviews'])
    df1 = pd.concat([df1, df2])
    print(next_cursor)
    if next_cursor == 'AoJ44PCp0tECd4WXSw==' or next_cursor == '*':
        df_steam_reviews = df1
        df1 = None
        break
        
# AoJ4tq3e6tQCdIacWA==
# AoJ4/JjZy9QCcu%2BmVw==
# AoJ4/oHpsdQCdJTRVg==
# AoJwpqK/jtQCfarOVQ==
# AoJ47/zY8tMCd9nvVA==
# AoJ4i%2BrR1dMCe8KGVA==
# AoJwi%2BnltdMCe/2QUw==
# AoJ42vfknNMCdrGvUg==
# AoJwkfiTidMCeKLbUQ==
# AoJ4ntGc9dICcL2JUQ==
# AoJwrImh5tICeJnDUA==
# AoJ44Iqz19ICfIP6Tw==
# AoJw7db0xNICe/axTw==
# AoJwjP7ZtdICfqv1Tg==
# AoJw5sbcqdICcePKTg==
# AoJ4r6DhotICd5OtTg==
# AoJwgpGHnNICdPKXTg==
# AoJ4%2B%2B3YldICcP/%2BTQ==
# AoJwmOOsj9ICccniTQ==
# AoJwk439h9ICdcW%2BTQ==
# AoJwxMLngtICc%2BqbTQ==
# AoJ4nJ%2BQ/dECco/1TA==
# AoJw58uP%2BNECcIfVTA==
# AoJ4rfXE9NECdPC2TA==
# AoJ4iLHP8NECdf2cTA==
# AoJ43NrE7NECeOyFTA==
# AoJwkOu%2B6NECecfvSw==
# AoJwu9/i5dECep3dSw==
# AoJ4kOH24tECepWtSw==
# AoJ48Ino39ECftvFSw==
# AoJ4q7Lr3NECdbm5Sw==
# AoJwiZLB2tECdIqxSw==
# AoJwv4qa2NECcNiYSw==
# AoJ43sPI1tECe%2BmlSw==
# AoJ4xO2y1dECc4yhSw==
# AoJ4roGW1NECevidSw==
# AoJ4xZzF09ECdcCbSw==
# AoJ4/7T/0tECcfiYSw==
# AoJwv4Su0tECcIaXSw==
# AoJ44PCp0tECd4WXSw==

# %%
# inspect columns
print(df_steam_reviews.info(verbose=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51321 entries, 0 to 20
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   recommendationid                51321 non-null  object
#  1   language                        51321 non-null  object
#  2   review                          51321 non-null  object
#  3   timestamp_created               51321 non-null  int64
#  4   timestamp_updated               51321 non-null  int64
#  5   voted_up                        51321 non-null  bool
#  6   votes_up                        51321 non-null  int64
#  7   votes_funny                     51321 non-null  int64
#  8   weighted_vote_score             51321 non-null  object
#  9   comment_count                   51321 non-null  int64
#  10  steam_purchase                  51321 non-null  bool
#  11  received_for_free               51321 non-null  bool
#  12  written_during_early_access     51321 non-null  bool
#  13  author.steamid                  51321 non-null  object
#  14  author.num_games_owned          51321 non-null  int64
#  15  author.num_reviews              51321 non-null  int64
#  16  author.playtime_forever         51321 non-null  int64
#  17  author.playtime_last_two_weeks  51321 non-null  int64
#  18  author.last_played              51321 non-null  int64
#  19  timestamp_dev_responded         1 non-null      float64
#  20  developer_response              1 non-null      object
# dtypes: bool(4), float64(1), int64(10), object(6)
# memory usage: 7.2+ MB
# None

# %%
# inspect shape
print(df_steam_reviews.shape)
# Out:
# (51321, 21)

# %%
# inspect df
df_steam_reviews
# Out:
#    recommendationid language  \
# 0          71182846  russian
# 1          71182712  english
# 2          71181661  turkish
# 3          71180994  russian
# 4          57766737  russian
# ..              ...      ...
# 16         19708009  english
# 17         19708002  english
# 18         19707993  english
# 19         19707992  english
# 20         19707991  english
#
#                                                review  timestamp_created  \
# 0   When I just joined the battle, my squad was at...         1592842434
# 1   Game is fun and exciting when it works. Very s...         1592842261
# 2   Valla efsane oyun beyler. Takım oyunu yapmama ...         1592840698
# 3                                                 TOP         1592839610
# 4   Очень хочу, чтобы в русской локализации игру н...         1574601186
# ..                                                ...                ...
# 16  Communication and teamplay is one of the best ...         1450166529
# 17  If you're looking for a realistic mil-sim styl...         1450166484
# 18  ITS THE BEST GAME EVERS \n\nPlay this game if ...         1450166426
# 19  (Disclaimer: This game used to not be on Steam...         1450166424
# 20                                           gg 10/10         1450166421
#
#     timestamp_updated  voted_up  votes_up  votes_funny   weighted_vote_score  \
# 0          1592842434      True         0            0                     0
# 1          1592842261     False         0            0                     0
# 2          1592840698      True         1            0  0.523809552192687988
# 3          1592839610      True         0            0                     0
# 4          1592837322      True         0            0                     0
# ..                ...       ...       ...          ...                   ...
# 16         1450166529      True        44            3  0.566995859146118164
# 17         1450166484      True        38            2   0.63659060001373291
# 18         1450166426      True       205          517  0.549310982227325439
# 19         1450166424      True       157            9  0.790276587009429932
# 20         1450166421      True        23            7   0.43365013599395752
#
#     comment_count  ...  received_for_free  written_during_early_access  \
# 0               0  ...              False                         True
# 1               0  ...              False                         True
# 2               0  ...              False                         True
# 3               0  ...              False                         True
# 4               0  ...              False                         True
# ..            ...  ...                ...                          ...
# 16              0  ...              False                         True
# 17              0  ...              False                         True
# 18             13  ...              False                         True
# 19              0  ...              False                         True
# 20              0  ...              False                         True
#
#        author.steamid author.num_games_owned  author.num_reviews  \
# 0   76561198271837310                     77                   1
# 1   76561198055021933                    150                  17
# 2   76561198380703693                     56                   8
# 3   76561198127609061                     66                   3
# 4   76561198105740539                    549                  14
# ..                ...                    ...                 ...
# 16  76561198014615390                    251                   2
# 17  76561198066675517                    543                   9
# 18  76561198048218734                     93                  11
# 19  76561198038225005                    253                   8
# 20  76561198120240821                    115                   5
#
#     author.playtime_forever  author.playtime_last_two_weeks  \
# 0                       364                             364
# 1                       316                              52
# 2                      6446                            1323
# 3                      4879                               1
# 4                     57627                            7599
# ..                      ...                             ...
# 16                    13623                               0
# 17                     4512                               0
# 18                   112520                               0
# 19                     3969                               0
# 20                    11239                               0
#
#     author.last_played  timestamp_dev_responded  developer_response
# 0           1592848618                      NaN                 NaN
# 1           1592843901                      NaN                 NaN
# 2           1592837756                      NaN                 NaN
# 3           1592842083                      NaN                 NaN
# 4           1592848771                      NaN                 NaN
# ..                 ...                      ...                 ...
# 16          1589089421                      NaN                 NaN
# 17          1587823021                      NaN                 NaN
# 18          1591500969                      NaN                 NaN
# 19          1589425139                      NaN                 NaN
# 20          1555782682                      NaN                 NaN
#
# [51321 rows x 21 columns]

# %%
# save that sheet
df_steam_reviews.to_csv('squad_reviews.csv', index=False)

# %% [markdown]
# ## 1.2 Clean

# %%
#search for presence of empty cells
df_steam_reviews.isnull().sum(axis = 0)
# Out:
# recommendationid                      0
# language                              0
# review                                0
# timestamp_created                     0
# timestamp_updated                     0
# voted_up                              0
# votes_up                              0
# votes_funny                           0
# weighted_vote_score                   0
# comment_count                         0
# steam_purchase                        0
# received_for_free                     0
# written_during_early_access           0
# author.steamid                        0
# author.num_games_owned                0
# author.num_reviews                    0
# author.playtime_forever               0
# author.playtime_last_two_weeks        0
# author.last_played                    0
# timestamp_dev_responded           51320
# developer_response                51320
# dtype: int64

# %%
#drop empty cols 'timestamp_dev_responded' and 'developer_response'
df_steam_reviews = df_steam_reviews.drop(['timestamp_dev_responded', 'developer_response'], axis=1)

# %%
# convert unix timestamp columns to datetime format
def time_to_clean(x):
    return datetime.fromtimestamp(x)

df_steam_reviews['timestamp_created'] = df_steam_reviews['timestamp_created'].apply(time_to_clean)
df_steam_reviews['timestamp_updated'] = df_steam_reviews['timestamp_updated'].apply(time_to_clean)
df_steam_reviews['author.last_played'] = df_steam_reviews['author.last_played'].apply(time_to_clean)

# %%
# inspect
df_steam_reviews
# Out:
#    recommendationid language  \
# 0          71182846  russian
# 1          71182712  english
# 2          71181661  turkish
# 3          71180994  russian
# 4          57766737  russian
# ..              ...      ...
# 16         19708009  english
# 17         19708002  english
# 18         19707993  english
# 19         19707992  english
# 20         19707991  english
#
#                                                review   timestamp_created  \
# 0   When I just joined the battle, my squad was at... 2020-06-22 11:13:54
# 1   Game is fun and exciting when it works. Very s... 2020-06-22 11:11:01
# 2   Valla efsane oyun beyler. Takım oyunu yapmama ... 2020-06-22 10:44:58
# 3                                                 TOP 2020-06-22 10:26:50
# 4   Очень хочу, чтобы в русской локализации игру н... 2019-11-24 07:13:06
# ..                                                ...                 ...
# 16  Communication and teamplay is one of the best ... 2015-12-15 02:02:09
# 17  If you're looking for a realistic mil-sim styl... 2015-12-15 02:01:24
# 18  ITS THE BEST GAME EVERS \n\nPlay this game if ... 2015-12-15 02:00:26
# 19  (Disclaimer: This game used to not be on Steam... 2015-12-15 02:00:24
# 20                                           gg 10/10 2015-12-15 02:00:21
#
#      timestamp_updated  voted_up  votes_up  votes_funny   weighted_vote_score  \
# 0  2020-06-22 11:13:54      True         0            0                     0
# 1  2020-06-22 11:11:01     False         0            0                     0
# 2  2020-06-22 10:44:58      True         1            0  0.523809552192687988
# 3  2020-06-22 10:26:50      True         0            0                     0
# 4  2020-06-22 09:48:42      True         0            0                     0
# ..                 ...       ...       ...          ...                   ...
# 16 2015-12-15 02:02:09      True        44            3  0.566995859146118164
# 17 2015-12-15 02:01:24      True        38            2   0.63659060001373291
# 18 2015-12-15 02:00:26      True       205          517  0.549310982227325439
# 19 2015-12-15 02:00:24      True       157            9  0.790276587009429932
# 20 2015-12-15 02:00:21      True        23            7   0.43365013599395752
#
#     comment_count  steam_purchase  received_for_free  \
# 0               0            True              False
# 1               0            True              False
# 2               0            True              False
# 3               0            True              False
# 4               0            True              False
# ..            ...             ...                ...
# 16              0           False              False
# 17              0           False              False
# 18             13           False              False
# 19              0           False              False
# 20              0           False              False
#
#     written_during_early_access     author.steamid  author.num_games_owned  \
# 0                          True  76561198271837310                      77
# 1                          True  76561198055021933                     150
# 2                          True  76561198380703693                      56
# 3                          True  76561198127609061                      66
# 4                          True  76561198105740539                     549
# ..                          ...                ...                     ...
# 16                         True  76561198014615390                     251
# 17                         True  76561198066675517                     543
# 18                         True  76561198048218734                      93
# 19                         True  76561198038225005                     253
# 20                         True  76561198120240821                     115
#
#     author.num_reviews  author.playtime_forever  \
# 0                    1                      364
# 1                   17                      316
# 2                    8                     6446
# 3                    3                     4879
# 4                   14                    57627
# ..                 ...                      ...
# 16                   2                    13623
# 17                   9                     4512
# 18                  11                   112520
# 19                   8                     3969
# 20                   5                    11239
#
#     author.playtime_last_two_weeks  author.last_played
# 0                              364 2020-06-22 12:56:58
# 1                               52 2020-06-22 11:38:21
# 2                             1323 2020-06-22 09:55:56
# 3                                1 2020-06-22 11:08:03
# 4                             7599 2020-06-22 12:59:31
# ..                             ...                 ...
# 16                               0 2020-05-10 00:43:41
# 17                               0 2020-04-25 08:57:01
# 18                               0 2020-06-06 22:36:09
# 19                               0 2020-05-13 21:58:59
# 20                               0 2019-04-20 12:51:22
#
# [51321 rows x 19 columns]

# %%
# save that sheet
df_steam_reviews.to_csv('game_reviews.csv', index=False)

# %% [markdown]
# # Misc

# %%
# list of free weekends:
Squad Free Weekend - Nov 2016
Squad Free Weekend - Apr 2017
Squad Free Weekend - Nov 2017
Squad Free Weekend - Jun 2018
Squad Free Weekend - Nov 2018
Squad Free Weekend - Jul 2019
Squad Free Weekend - Nov 2019

# list of major patch days:
v1 - July 1 2015
v2 - Oct 31 2015
v3 - Dec 15 2015
v4 - ?
v5 - Mar 30 2016
v6 - May 26 2016
v7 - Aug  7 2016
v8 - Nov  1 2016
v9 - Mar  9 2017
v10  Feb  5 2018
v11  Jun  6 2018
v12  Nov 29 2018
v13  May  ? 2019
v14  Jun 28 2019
v15  Jul 22 2019
v16  Oct 10 2019
v17  Nov 25 2019
v18  ?
v19  May  2 2020

# %% [markdown]
# ![Rating-Formula](https://steamdb.info/static/img/blog/84/formula.png)

# %%
#v2 (fromhttps://cloud.google.com/translate/docs/simple-translate-call#translate_translate_text-python)
# translate/spellcheck via googletranslate pkg
from google.cloud import translate_v2 as translate

def time_to_translate(x):
    if x == None: # ignore the 'NaN' reviews
        return 'NaN'
    else:
        translate_client = translate.Client()
        if isinstance(x, six.binary_type):
            text = x.decode('utf-8')
            return text
        
#print(time_to_translate('hola'))

# %%
# scratch
df_steam_reviews = pd.read_csv('squad_reviews.csv', low_memory=False)

# %%
df_steam_reviews

# %%
# display reviews 
fig = px.histogram(df_steam_reviews, x="timestamp_created", color="voted_up", width=1000, height=500, title='Positive(True)/Negative(False) Reviews')
fig.show()

# %%
# translate/spellcheck t
t['review.translated'] = t['review'].progress_apply(time_to_translate)
t.to_csv('t.csv', index=False)
