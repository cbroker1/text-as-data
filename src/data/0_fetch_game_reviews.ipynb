# %% [markdown]
# # 1. User Reviews via Steam API (https://partner.steamgames.com/doc/store/getreviews)

# %%
# import packages
import os
import sys
import time
import json
import numpy as np
import urllib.parse
import urllib.request
from tqdm import tqdm
import plotly.express as px
from datetime import datetime
from googletrans import Translator

import pandas as pd
from pandas import json_normalize

# list package ver. etc.
print("Python version")
print (sys.version)
print("Version info.")
print (sys.version_info)
print('---------------')
# Out:
# Python version
# 3.8.3 (default, May 19 2020, 18:47:26)
# [GCC 7.3.0]
# Version info.
# sys.version_info(major=3, minor=8, micro=3, releaselevel='final', serial=0)
# ---------------

# %%
# %reload_ext watermark
# %watermark -v -p os,sys,time,json,numpy,urllib,tqdm,plotly,datetime,pandas
# Out:
# CPython 3.8.3
# IPython 7.15.0
#
# os unknown
# sys 3.8.3 (default, May 19 2020, 18:47:26)
# [GCC 7.3.0]
# time unknown
# json 2.0.9
# numpy 1.18.5
# urllib unknown
# tqdm 4.46.1
# plotly 4.8.1
# datetime unknown
# pandas 1.0.4

# %% [markdown]
# ---
# ### Data Dictionary:
#
# - Response:
#     - success - 1 if the query was successful
#     - query_summary - Returned in the first request
#         - recommendationid - The unique id of the recommendation
#         - author
#             - steamid - the user’s SteamID
#             - um_games_owned - number of games owned by the user
#             - num_reviews - number of reviews written by the user
#             - playtime_forever - lifetime playtime tracked in this app
#             - playtime_last_two_weeks - playtime tracked in the past two weeks for this app
#             - playtime_at_review - playtime when the review was written
#             - last_played - time for when the user last played
#         - language - language the user indicated when authoring the review
#         - review - text of written review
#         - timestamp_created - date the review was created (unix timestamp)
#         - timestamp_updated - date the review was last updated (unix timestamp)
#         - voted_up - true means it was a positive recommendation
#         - votes_up - the number of users that found this review helpful
#         - votes_funny - the number of users that found this review funny
#         - weighted_vote_score - helpfulness score
#         - comment_count - number of comments posted on this review
#         - steam_purchase - true if the user purchased the game on Steam
#         - received_for_free - true if the user checked a box saying they got the app for free
#         - written_during_early_access - true if the user posted this review while the game was in Early Access
#         - developer_response - text of the developer response, if any
#         - timestamp_dev_responded - Unix timestamp of when the developer responded, if applicable
#
# ---
# Source: https://partner.steamgames.com/doc/store/getreviews

# %% [markdown]
# ## 1.1 Import

# %%
# generate game review df

#steam 'chunks' their json files (the game reviews) in sets of 100
#ending with a signature, a 'cursor'. This cursor is then pasted
#onto the the same url, to 'grab' the next chunk and so on. 
#This sequence block with an 'end cursor' of 'AoJ4tey90tECcbOXSw=='

#set variables
url_base = 'https://store.steampowered.com/appreviews/393380?json=1&filter=updated&language=all&review_type=all&purchase_type=all&num_per_page=100&cursor='

#first pass
url = urllib.request.urlopen("https://store.steampowered.com/appreviews/393380?json=1&filter=updated&language=all&review_type=all&purchase_type=all&num_per_page=100&cursor=*")
data = json.loads(url.read().decode())
next_cursor = data['cursor']
next_cursor = next_cursor.replace('+', '%2B')
df1 = json_normalize(data['reviews'])
print(next_cursor)

#add results till stopcursor met, then send all results to csv
while True:
    time.sleep(0.5) # Sleep for half-second
    url_temp = url_base + next_cursor
    url = urllib.request.urlopen(url_temp)
    data = json.loads(url.read().decode())
    next_cursor = data['cursor']
    next_cursor = next_cursor.replace('+', '%2B')
    df2 = json_normalize(data['reviews'])
    df1 = pd.concat([df1, df2])
    print(next_cursor)
    if next_cursor == 'AoJ44PCp0tECd4WXSw==' or next_cursor == '*':
        df_steam_reviews = df1
        df1 = None
        df_game_reviews.to_csv(r'../data/raw/game_reviews_raw.csv', index=False)
        print('All finished! Check raw data directory for output.')
        break
        
#the hash below is each 'cursor' I loop through until the 'end cursor'.
#this is just my way to monitor the download.
# Out:
# AoJw6azIh/MCfZmUkgI=
# AoJ4kO6whPMCfu/pkQI=
# AoJ44fiAgvMCc%2BTGkQI=
# AoJwoKrN//ICesyikQI=
# AoJwzM7W%2B/ICddeWUQ==
# AoJwm/S/9/ICf5WgkAI=
# AoJwjfnA8vICe9LqjwI=
# AoJwhfX26vICe7ukjwI=
# AoJwhu3T5PICc6HrjgI=
# AoJ4l%2BvE3fICepaqjgI=
# AoJ4gZWG1/ICe/LljQI=
# AoJ4voqH0fICds6wjQI=
# AoJ4kJvTyvICeez4jAI=
# AoJw%2BKnAxPICfq6miwI=
# AoJ4/6S4wPICc6OWjAI=
# AoJ4oaeLu/ICdejmiwI=
# AoJ4pNaHt/ICcsjCiwI=
# AoJ4jrmzsfICdPmLiwI=
# AoJwzLGsq/ICcp/QigI=
# AoJw%2BY6Vp/ICev2migI=
# AoJ4yoCWo/ICedq/rgE=
# AoJw5b%2BRn/ICe/zNiQI=
# AoJw5/XvmvICd8ObiQI=
# AoJwqJWllvICcOLliAI=
# AoJ4mMWAkvICe%2BO5iAI=
# AoJ40N3ijfICcY%2BDiAI=
# AoJwtfPEivICdI/ghwI=
# AoJ4grS6hvICfNG0hwI=
# AoJ4po3Mg/ICeqOXhwI=
# AoJ4yNmngfICeMH/hgI=
# AoJ469Lm/vECecT1qQE=
# AoJwme%2Bt/PECebrLhgI=
# AoJwyPKR%2BvECevuzhgI=
# AoJwz/OF%2BfECf7KphgI=
# AoJ4o6/i%2BPECfdSmhgI=
# AoJ457uR%2BPECeZufhgI=
# AoJw5Jb%2B9vECee6QhgI=
# AoJwvLPg9fECfIaFhgI=
# AoJ4mPjM8/ECfb3thQI=
# AoJwt%2Bmj8fECdvPRhQI=
# AoJ4sOfb7/ECdf%2B%2BhQI=
# AoJwo7bb7vECeey0hQI=
# AoJ4iaP87fECfMyshQI=
# AoJwwpfX7fECcuaohQI=
# AoJ497LS7PECd/WbhQI=
# AoJ4u//C6/ECeuiPhQI=
# AoJ4pdni6vECdvyEhQI=
# AoJ43pn06fECevj6hAI=
# AoJ4tff46PECeZ3whAI=
# AoJwmrKc6PECc7nlhAI=
# AoJwgqz65vECc%2BnWhAI=
# AoJwpej54/ECdZa0hAI=
# AoJw1%2BmT3vECfrzwgwI=
# AoJ4o6Gg2PECeLqqgwI=
# AoJ4ld3o0fECffLjggI=
# AoJ4ka/xyvECd8iPggI=
# AoJ4rdS8xPECdKrBgQI=
# AoJw5/KKv/ECft7%2BgAI=
# AoJwi5m2ufECf%2Ba0gAI=
# AoJw4fDWtPECduqTuwE=
# AoJ4l6Kfr/ECcoGv1AE=
# AoJ4zrXtqPECdMzg/gE=
# AoJ4p7mIofECcbDo/QE=
# AoJwteGgm/ECeMqP/QE=
# AoJw9NfblPECd/Wj/AE=
# AoJ4sOjUkPECd/fn%2BwE=
# AoJw8MizjPECeMTmZQ==
# AoJwrIjUhvECeurY%2BgE=
# AoJw6OSUgfECe%2BGG%2BgE=
# AoJ4laXf%2BfACe9Ce%2BQE=
# AoJw0tep8/ACdtaTwQE=
# AoJwn/uL7fACceSN%2BAE=
# AoJ40Lbz5fACfePB9wE=
# AoJwyJPn3fACcL709gE=
# AoJ4i%2B6S2PACdfK29gE=
# AoJ47/C60PACc8nx9QE=
# AoJwgffPyvACcdm59QE=
# AoJw/7Ltw/ACcuT19AE=
# AoJwq/zJvPACeOmy9AE=
# AoJwrtfntvACcPz08wE=
# AoJw/anLr/ACcpet8wE=
# AoJwmdKVqfACcJvr8gE=
# AoJ4wPzepPACee%2B38gE=
# AoJwkqTXnfACfYPw8QE=
# AoJ44f7Xl/ACcsKv8QE=
# AoJwxvL0kvACfND98AE=
# AoJ4otSQjPACf6%2B68AE=
# AoJwivDPhfACef/%2B7wE=
# AoJwtoO4gPACfcnE7wE=
# AoJ4w%2Bzk%2Bu8CcvuG7wE=
# AoJwwYvm9O8CddLJ7gE=
# AoJ49P7C7%2B8Ce7SL7gE=
# AoJwjIGp6%2B8Cf/3a7QE=
# AoJw7vjA5e8Cermn7QE=
# AoJ4v/eW4O8CcOL47AE=
# AoJ4ioOX3O8Ce5fN7AE=
# AoJwwefO1u8Cfoqb7AE=
# AoJ4yaei0u8Cfej16wE=
# AoJwuYLUze8Ce8jKSw==
# AoJw6rG6yu8Cd%2Bym6wE=
# AoJwruXoxe8Cd7z36gE=
# AoJwiOrCwO8CdrXE6gE=
# AoJ43MLOu%2B8CcuyQ6gE=
# AoJ4pcPBuO8Cf4zm6QE=
# AoJw78eCte8Cebu36QE=
# AoJ43bbise8Ce4qkZQ==
# AoJ43Jbaru8CcOrd6AE=
# AoJwm8z%2Bqu8Ccain6AE=
# AoJ46/HPp%2B8Cc9/15wE=
# AoJwhYW7pO8CeebE5wE=
# AoJw/c7Ioe8CdqOZ5wE=
# AoJ4lLSOne8CeZbf5gE=
# AoJwo9fqmO8CfIKm5gE=
# AoJw/pLyle8Cd8H95QE=
# AoJ41YXvku8CdeXU5QE=
# AoJwxPWkj%2B8CfJyr5QE=
# AoJwvKS7jO8Ce8eQ5QE=
# AoJw15H3h%2B8Ccfvh5AE=
# AoJwk7Oeg%2B8CfLmu5AE=
# AoJ4y%2B6a/u4CddHw4wE=
# AoJ4n6a4%2Be4CcfvB4wE=
# AoJ4/IKc9e4Ce9GV4wE=
# AoJ46cqd8u4Cd/vx4gE=
# AoJw5KHX7%2B4CfLrM4gE=
# AoJ466ya7e4CevSq4gE=
# AoJ4otOs6u4CdquJ4gE=
# AoJwstqt5u4CddHT4QE=
# AoJ4qf6h5O4CcIeq4QE=
# AoJw9L674u4Ccs%2BC4QE=
# AoJ494P34O4CfvvZ4AE=
# AoJ496%2BY3%2B4Ce52r4AE=
# AoJw97Kh3u4Cf92iyAE=
# AoJw0vL33O4Cfvnh3wE=
# AoJw54/v2%2B4CfeqPkQE=
# AoJ4uKCz2u4Cdv6W3wE=
# AoJ46six2e4Cft/z3gE=
# AoJ4%2B/%2BE2O4CePqZywE=
# AoJ47Zid1%2B4CcZOq3gE=
# AoJ4yajy1u4Ce6qT3gE=
# AoJw/sij1u4Ccr/m3QE=
# AoJw5O641e4CcLC73QE=
# AoJwmfrp1O4CcLPFZQ==
# AoJ43p780%2B4CcNjg3AE=
# AoJwovCh0e4CdcrI3AE=
# AoJw1fv0zu4Cecmw3AE=
# AoJ4ufzazO4CccmV3AE=
# AoJw/%2B%2Bsyu4Cc%2Br22wE=
# AoJwgpykyO4CfYeozwE=
# AoJ43qv4xe4Ce6rK2wE=
# AoJwpMC/w%2B4CdL%2Bx2wE=
# AoJwh//Pwe4CcLCc2wE=
# AoJw4oCRwO4CdOGO2wE=
# AoJwqffGv%2B4CdeCH2wE=
# AoJwuL2xvu4CcKf92gE=
# AoJ4it61ve4CcLLz2gE=
# AoJwo/bQvO4CcrHm2gE=
# AoJ4i%2BbUu%2B4Cd4fa2gE=
# AoJ44eHduu4CdrzN2gE=
# AoJ4gNjSue4CedS72gE=
# AoJwxJaluO4CfvWq2gE=
# AoJwrcDltu4CdPqX2gE=
# AoJ4qfrftO4Cd9aC2gE=
# AoJ476LJsO4CdObW2QE=
# AoJ4npWMre4Cdt%2Bu2QE=
# AoJ4joHVqu4Cee%2BQ2QE=
# AoJwyIzKqO4Cd4Dy2AE=
# AoJwz/7Ipe4CfMDB2AE=
# AoJ49Yeoou4CcO6Z2AE=
# AoJwgvfXn%2B4CcqD51wE=
# AoJ40rPIne4CcaXb1wE=
# AoJwhLazm%2B4CfbO%2B1wE=
# AoJwx52sme4Cdu6g1wE=
# AoJ4q62KmO4Ce46D1wE=
# AoJ408fylu4Cc5Dt1gE=
# AoJwhb7ele4CeqDM1gE=
# AoJ4ysamlO4Cf4Cu1gE=
# AoJwrcelk%2B4CfbWN1gE=
# AoJw6%2Bb7ke4CcvPy1QE=
# AoJwi8GVke4Cfo/Y1QE=
# AoJwzMOekO4Cdsu51QE=
# AoJwns%2Bwj%2B4CdrSm1QE=
# AoJ4kpODh%2B4Cc/6A1QE=
# AoJ44o/L/%2B0Cf4/V1AE=
# AoJwnsOO8u0Cddmu1AE=
# AoJwjr7q5%2B0CdIGU1AE=
# AoJwtPi02u0CdtLs0wE=
# AoJw8fnPyu0Ccuu80wE=
# AoJ4wv39te0CcfWNdQ==
# AoJw6YTbpe0CeYPE0gE=
# AoJw%2B4qHlu0CcYeW0gE=
# AoJ4rNbdhO0CeZvl0QE=
# AoJw15Px8%2BwCfvGdiwE=
# AoJwrMrL5OwCeouF0QE=
# AoJ4lqvu0ewCeejJ0AE=
# AoJwzsWbxewCfomi0AE=
# AoJ4776Hu%2BwCdZrMmwE=
# AoJ486KgsewCcNzlzwE=
# AoJw06/XquwCeZ%2BTzwE=
# AoJ4jIqbouwCcde3zwE=
# AoJ4/%2B%2B%2BnuwCc8%2BrzwE=
# AoJ49buOnewCevmnzwE=
# AoJw/L%2BInOwCfuajzwE=
# AoJ4q%2BWtmuwCctiezwE=
# AoJwpZj%2BmOwCdtKZzwE=
# AoJwibW1l%2BwCdcWUzwE=
# AoJwvMKxlewCcY6OzwE=
# AoJwu4iXjewCfJH0gAE=
# AoJw9N6bgOwCeKDDugE=
# AoJ4/5O09OsCe62ezgE=
# AoJw64Cn6%2BsCeoH5zQE=
# AoJw4qKC5usCdeDPzQE=
# AoJ4i%2B6b5OsCcruozQE=
# AoJ40K2v4usCeO/7zAE=
# AoJwyOHx4OsCet/RzAE=
# AoJ4%2B72g3%2BsCcKurzAE=
# AoJwrM%2BR3usCe8mFzAE=
# AoJ4%2BY3V3OsCd/feywE=
# AoJwoMPJ2%2BsCcOqzywE=
# AoJ47vqq2usCfLWOywE=
# AoJ41tW82esCf7viygE=
# AoJ42JC62OsCd623ygE=
# AoJ41o3a1%2BsCeLaWygE=
# AoJw9a6b1%2BsCcuPvyQE=
# AoJwxrbm1usCeNTJyQE=
# AoJwkZqU1usCeNqdyQE=
# AoJ4h5nJ1esCf7X%2ByAE=
# AoJ404GR1esCdIzbyAE=
# AoJwqubt1OsCd9m1yAE=
# AoJwr7C51OsCdPmNyAE=
# AoJwqZDx0%2BsCf6LkxwE=
# AoJ4sraJ0%2BsCcN6zxwE=
# AoJwiuy90usCf8SGxwE=
# AoJw37OP0usCcOvXxgE=
# AoJw/Nfk0esCdtikxgE=
# AoJw4Jq20esCfbfnxQE=
# AoJw3pn/0OsCcumgxQE=
# AoJ4lJLL0OsCcvbsxAE=
# AoJ4zqjizesCc7vAxAE=
# AoJ4wonfxOsCf8KUxAE=
# AoJ4vdWesesCfN7HwwE=
# AoJ4w7mtoesCdICVwwE=
# AoJ46JOcl%2BsCfsbwwgE=
# AoJwyOath%2BsCff%2B6wgE=
# AoJwmbi69%2BoCduTzwQE=
# AoJwtZ%2BO5%2BoCdbO6wQE=
# AoJwtLfE1%2BoCetqMwQE=
# AoJw9NjaxeoCfajVwAE=
# AoJwk73zuuoCeYuswAE=
# AoJ44%2BPWo%2BoCdbPLtAE=
# AoJw18vnh%2BoCfduIvwE=
# AoJ4kJmS7ekCdMqsvgE=
# AoJ47umt0%2BkCerXLvQE=
# AoJwi7%2Bws%2BkCe7zevAE=
# AoJ4oZmvlOkCeoOFcw==
# AoJw46LW%2BOgCe6/5ugE=
# AoJwy7XK3%2BgCduWLugE=
# AoJwq7OvyegCcNSzuQE=
# AoJwkpqfregCcovGuAE=
# AoJw1OTElugCc5HotwE=
# AoJ4oMnmhOgCfcKndg==
# AoJwtf/T%2BOcCeezQtgE=
# AoJwg4T06ucCfeL9tQE=
# AoJw%2BuHf2ecCd5ShoAE=
# AoJ417y0yucCdce0ZQ==
# AoJwucfQtecCebCatAE=
# AoJwqKP0qecCdprZswE=
# AoJ46LeEp%2BcCddmnswE=
# AoJ4zc6vpecCdZr7sgE=
# AoJws4zHo%2BcCeMfMsgE=
# AoJwn7GyoucCedCgsgE=
# AoJwwKeLoecCdt39sQE=
# AoJ46sugoOcCd%2BGbZQ==
# AoJ4/NvynucCcpT%2BqAE=
# AoJwrMKpnucCequFsQE=
# AoJ4iu/7necCcYO9jQE=
# AoJ47vO3necCdICwsAE=
# AoJ4%2BYnqnOcCftaHsAE=
# AoJ4tcilnOcCfYesUA==
# AoJwnJD8m%2BcCddm%2BrwE=
# AoJ4xPOhmOcCdLaRrwE=
# AoJ4sszXi%2BcCd5vnrgE=
# AoJ4k/69hucCeLTYrgE=
# AoJwuPyPhOcCfb7RrgE=
# AoJ4ytbvgecCf5vKrgE=
# AoJ47oq0gOcCeMLErgE=
# AoJwzqSr/%2BYCd8fArgE=
# AoJwtvDB/uYCcde8rgE=
# AoJ4woS5/OYCfKe1rgE=
# AoJwp%2ByY4%2BYCeJDUrQE=
# AoJ4qY2zy%2BYCe4OMrQE=
# AoJ43t/NruYCfKCFnAE=
# AoJwrueQjuYCdYvGqwE=
# AoJwiejS8OUCf/nfqgE=
# AoJ47sPMy%2BUCfJzpqQE=
# AoJ4vsy0uOUCe%2BCfqQE=
# AoJwov3OpOUCePnUqAE=
# AoJ4%2BtmhkeUCfqD%2BpwE=
# AoJwxJy0%2BuQCd/zWmAE=
# AoJw8dLT6OQCc9%2BApAE=
# AoJ4krun2uQCduu4pgE=
# AoJ4x%2BH8yuQCd7mkWw==
# AoJwx6TuvOQCcebGpQE=
# AoJw5KOasuQCd5uSpQE=
# AoJ4w5XgqeQCepXnpAE=
# AoJwso/4oOQCd5i2pAE=
# AoJwl%2BnymeQCf%2BmMpAE=
# AoJ4l9H/leQCdf/wowE=
# AoJ4wtShkuQCdP3YowE=
# AoJwocHfg%2BQCdqeonwE=
# AoJ4z9ia8%2BMCdbHomAE=
# AoJwy4L/4uMCdeGBogE=
# AoJ4rI2M0%2BMCcua%2BoQE=
# AoJw3/eaw%2BMCee/voAE=
# AoJ4z8zwruMCfJ2roAE=
# AoJw%2Bebtn%2BMCe8D0nwE=
# AoJ48KPIleMCfK/QnwE=
# AoJ4gou9/%2BICd66EnwE=

# %%
# inspect columns
print(df_steam_reviews.info(verbose=True))

# %%
# inspect shape
print(df_steam_reviews.shape)

# %%
# inspect df
df_steam_reviews

# %%
# save that sheet
df_steam_reviews.to_csv('squad_reviews.csv', index=False)

# %% [markdown]
# ## 1.2 Clean

# %%
#search for presence of empty cells
df_steam_reviews.isnull().sum(axis = 0)

# %%
#drop empty cols 'timestamp_dev_responded' and 'developer_response'
df_steam_reviews = df_steam_reviews.drop(['timestamp_dev_responded', 'developer_response'], axis=1)

# %%
# convert unix timestamp columns to datetime format
def time_to_clean(x):
    return datetime.fromtimestamp(x)

df_steam_reviews['timestamp_created'] = df_steam_reviews['timestamp_created'].apply(time_to_clean)
df_steam_reviews['timestamp_updated'] = df_steam_reviews['timestamp_updated'].apply(time_to_clean)
df_steam_reviews['author.last_played'] = df_steam_reviews['author.last_played'].apply(time_to_clean)

# %%
# inspect
df_steam_reviews

# %%
# save that sheet
df_steam_reviews.to_csv('game_reviews.csv', index=False)

# %% [markdown]
# # Misc

# %%
# list of free weekends:
Squad Free Weekend - Nov 2016
Squad Free Weekend - Apr 2017
Squad Free Weekend - Nov 2017
Squad Free Weekend - Jun 2018
Squad Free Weekend - Nov 2018
Squad Free Weekend - Jul 2019
Squad Free Weekend - Nov 2019

# list of major patch days:
v1 - July 1 2015
v2 - Oct 31 2015
v3 - Dec 15 2015
v4 - ?
v5 - Mar 30 2016
v6 - May 26 2016
v7 - Aug  7 2016
v8 - Nov  1 2016
v9 - Mar  9 2017
v10  Feb  5 2018
v11  Jun  6 2018
v12  Nov 29 2018
v13  May  ? 2019
v14  Jun 28 2019
v15  Jul 22 2019
v16  Oct 10 2019
v17  Nov 25 2019
v18  ?
v19  May  2 2020

# %% [markdown]
# ![Rating-Formula](https://steamdb.info/static/img/blog/84/formula.png)

# %%
#v2 (fromhttps://cloud.google.com/translate/docs/simple-translate-call#translate_translate_text-python)
# translate/spellcheck via googletranslate pkg
from google.cloud import translate_v2 as translate

def time_to_translate(x):
    if x == None: # ignore the 'NaN' reviews
        return 'NaN'
    else:
        translate_client = translate.Client()
        if isinstance(x, six.binary_type):
            text = x.decode('utf-8')
            return text
        
#print(time_to_translate('hola'))

# %%
# scratch
df_steam_reviews = pd.read_csv('squad_reviews.csv', low_memory=False)

# %%
df_steam_reviews

# %%
# display reviews 
fig = px.histogram(df_steam_reviews, x="timestamp_created", color="voted_up", width=1000, height=500, title='Positive(True)/Negative(False) Reviews')
fig.show()

# %%
# translate/spellcheck t
t['review.translated'] = t['review'].progress_apply(time_to_translate)
t.to_csv('t.csv', index=False)
